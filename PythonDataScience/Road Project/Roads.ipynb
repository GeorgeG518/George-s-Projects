# %%
import pandas as pd 
import seaborn as sns
import numpy as np
 
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
from matplotlib import style

# %%
# Set display to show up to 100 columns in dataframe
pd.set_option('display.max_columns',100)

# %%
# Read CSV file into dataframe
df_roads = pd.read_csv("Traffic History.csv")

# %%
# Provide a listing of the field names in the dataframe
df_roads.columns.values
# Out:
# array(['OBJECTID', 'STATION_ID', 'STN_NUMBER', 'COUNTY', 'LOCATION',
#        'RTE_NUMBER', 'AADT_2018', 'AADT_2017', 'AADT_2016', 'AADT_2015',
#        'AADT_2014', 'AADT_2013', 'AADT_2012', 'AADT_2011', 'AADT_2010',
#        'AADT_2009', 'AADT_2008', 'AADT_2007', 'AADT_2006', 'AADT_2005',
#        'AADT_2004', 'AADT_2003', 'AADT_2002', 'AADT_2001', 'AADT_2000',
#        'AADT_1999', 'AADT_1998', 'AADT_1997', 'AADT_1996', 'AADT_1995',
#        'AADT_1994', 'AADT_1993', 'AADT_1992', 'AADT_1991', 'AADT_1990',
#        'AADT_1989', 'AADT_1988', 'AADT_1987', 'AADT_1986', 'AADT_1985',
#        'AADT_1984', 'AADT_1983'], dtype=object)

# %%
df_roads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 42 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    66 non-null     int64
#  1   STATION_ID  66 non-null     int64
#  2   STN_NUMBER  66 non-null     int64
#  3   COUNTY      66 non-null     object
#  4   LOCATION    66 non-null     object
#  5   RTE_NUMBER  66 non-null     object
#  6   AADT_2018   66 non-null     int64
#  7   AADT_2017   66 non-null     int64
#  8   AADT_2016   66 non-null     int64
#  9   AADT_2015   66 non-null     int64
#  10  AADT_2014   66 non-null     int64
#  11  AADT_2013   66 non-null     int64
#  12  AADT_2012   66 non-null     int64
#  13  AADT_2011   66 non-null     int64
#  14  AADT_2010   66 non-null     int64
#  15  AADT_2009   66 non-null     int64
#  16  AADT_2008   66 non-null     int64
#  17  AADT_2007   65 non-null     float64
#  18  AADT_2006   65 non-null     float64
# ...

# %%
df_roads.describe()
# Out:
#            OBJECTID    STATION_ID  STN_NUMBER     AADT_2018     AADT_2017  \
# count     66.000000  6.600000e+01   66.000000     66.000000     66.000000
# mean    8406.924242  3.100014e+07  141.212121   7620.969697   7341.439394
# std     2910.789147  1.245026e+02  124.502643  11319.042358  10618.383273
# min     1493.000000  3.100001e+07    8.000000     40.000000     44.000000
# 25%     6609.250000  3.100009e+07   86.250000   1090.250000   1178.000000
# 50%     9068.500000  3.100013e+07  127.500000   2872.500000   2981.500000
# 75%    10503.750000  3.100020e+07  200.750000   9621.000000   9077.000000
# max    12894.000000  3.100099e+07  990.000000  49203.000000  45276.000000
#
#           AADT_2016     AADT_2015     AADT_2014     AADT_2013     AADT_2012  \
# count     66.000000     66.000000     66.000000     66.000000     66.000000
# mean    7132.484848   7048.409091   6922.984848   6817.484848   6851.530303
# ...

# %%
df_roads.head(1)
# Out:
#    OBJECTID  STATION_ID  STN_NUMBER  COUNTY          LOCATION RTE_NUMBER  \
# 0      1493    31000008           8  Coffee  NW OF MANCHESTER      SR280
#
#    AADT_2018  AADT_2017  AADT_2016  AADT_2015  AADT_2014  AADT_2013  \
# 0       1543       1420       1358       1330       1467       1281
#
#    AADT_2012  AADT_2011  AADT_2010  AADT_2009  AADT_2008  AADT_2007  \
# 0       1174       1179       1369       1190       1114     1350.0
#
#    AADT_2006  AADT_2005  AADT_2004  AADT_2003  AADT_2002  AADT_2001  \
# 0     1254.0     1192.0     1088.0     1038.0      982.0     1007.0
#
#    AADT_2000  AADT_1999  AADT_1998  AADT_1997  AADT_1996  AADT_1995  \
# 0     1051.0     1010.0      968.0      861.0      890.0      923.0
#
#    AADT_1994  AADT_1993  AADT_1992  AADT_1991  AADT_1990  AADT_1989  \
# 0      840.0      811.0      765.0      720.0      724.0      785.0
#
#    AADT_1988  AADT_1987  AADT_1986  AADT_1985  AADT_1984  AADT_1983
# ...

# %%
# Gets rid of the state routes
df_wo_state_roads = df_roads[~df_roads['RTE_NUMBER'].str.contains('SR')]

# %%
df_wo_state_roads.sample(5)
# Out:
#     OBJECTID  STATION_ID  STN_NUMBER  COUNTY  \
# 8       2485    31000046          46  Coffee
# 48     11024    31000200         200  Coffee
# 30      7963    31000114         114  Coffee
# 29     10012    31000108         108  Coffee
# 2       1835    31000029          29  Coffee
#
#                                   LOCATION RTE_NUMBER  AADT_2018  AADT_2017  \
# 8           MANCHESTER RD-SOUTH MANCHESTER      04664       2517       2592
# 48                              MANCHESTER      04663       2609       2385
# 30                    COFFEE ST-MANCHESTER      01111       4418       3371
# 29                        NORTH MANCHESTER      I0024      49203      45276
# 2   MARKEELE RD. - NORTHEAST OF MANCHESTER      0A466         40         44
#
#     AADT_2016  AADT_2015  AADT_2014  AADT_2013  AADT_2012  AADT_2011  \
# 8        2556       2539       2302       2371       2725       2419
# 48       2311       2277       2299       2129       2126       2005
# ...

# %%
df_roads=df_wo_state_roads

# %%
df_roads.sample(5)
# Out:
#     OBJECTID  STATION_ID  STN_NUMBER  COUNTY                    LOCATION  \
# 53     11822    31000205         205  Coffee                  MANCHESTER
# 28      9120    31000106         106  Coffee      WOODLAND ST-MANCHESTER
# 58     10058    31000216         216  Coffee        FORT ST - MANCHESTER
# 39      5252    31000134         134  Coffee     CAT CREEK RD-MANCHESTER
# 55     10956    31000208         208  Coffee  S. RAMSEY ST. - MANCHESTER
#
#    RTE_NUMBER  AADT_2018  AADT_2017  AADT_2016  AADT_2015  AADT_2014  \
# 53      01111       3136       3848       3163       3129       3064
# 28      03411       3742       3903       4000       3932       3707
# 58      03412       1127       1754       1727       1683       1678
# 39      01111       1004       1156       1126       1115       1083
# 55      0A771        526        940        931        883        865
#
#     AADT_2013  AADT_2012  AADT_2011  AADT_2010  AADT_2009  AADT_2008  \
# ...
