# %% [markdown]
# # Python 1 Assignment
# ### Purpose: To explore different ways in which data can be brought in to Python via
# - Excel files
# - CSV files
# - Website data

# %%
# Bring in standard libraries and set "call" name to ease access
import pandas as pd

# Set display to show up to 100 columns in dataframe
pd.set_option('display.max_columns',100)

# %% [markdown]
# ### Read Excel File

# %%
# Read Excel file into dataframe
df_excel =  pd.ExcelFile('DataFinder Data Sample.xlsx') 

# Show worksheet names in dataframe from Excel file 
print(df_excel.sheet_names)
# Out:
# ['Sheet1', 'Data']

# %%
# Load data from specific worksheet into dataframe
df_datafinder = df_excel.parse('Data')

# Show data in top two rows
df_datafinder.head(2)
# Out:
#           City    County State    Zip Country         DOB  \
# 0  WESTERVILLE  Delaware    OH  43082      US  05/01/1951
# 1  OLMSTED TWP  Cuyahoga    OH  44138      US  06/26/1954
#
#                   URLSource  AutoYear   Make    Model AutoTrim  \
# 0           GETYOURGIFT.COM    2012.0  ACURA      RDX    WAGON
# 1  BESTSENIORCAREONLINE.COM    2005.0  HONDA  ODYSSEY      VAN
#
#              AutoVIN  Gender                    Source  Last4SSN  \
# 0  5J8TB1H53CA003133  Female           GETYOURGIFT.COM    9246.0
# 1  5FNRL38475B020844    Male  BESTSENIORCAREONLINE.COM    2954.0
#
#                   Employer                                    Occupation  \
# 0  UNCOMMON THREAD IMPORTS                                         Other
# 1                      NaN  Management/Business and Financial Operations
#
#    LoanAmount   LoanType  MonthlyIncome EstimatedHouseholdIncome  \
# 0    304000.0  REFINANCE            0.0         $100,000-149,999
# 1         NaN        NaN            NaN           $75,000-99,999
#
#            NetWorth  NumberCreditLines RangeOfNewCredit          Education  \
# 0  $250,000-499,999                5.0       $501-1,000       Some College
# 1  $100,000-249,999                1.0        > $10,000  Completed College
#
#     OccupationDetail  NumberOfChildren PresenceOfChildren  \
# 0             Beauty               1.0                  Y
# 1  Middle Management               2.0                  Y
#
#   MaritalStatusInHousehold HomeOwnerRenter  LengthOfResidence DwellingType  \
# 0                        M               H                  9            S
# 1                        M               H                  8            S
#
#    NumberOfAdults  HouseholdSize  GenerationsInHousehold MailOrderBuyer  \
# 0               3              4                     2.0              Y
# 1               5              7                     2.0              Y
#
#   MailerOrderResponder OnlinePurchasingIndicator MembershipClubs  \
# 0                    Y                         Y               N
# 1                    Y                         Y               N
#
#   ValuePriceGeneralMerchandiseBuyer ApparelWomens ApparelWomensPetite  \
# 0                                 N             Y                   N
# 1                                 N             Y                   N
#
#   ApparelWomensPlusSize ApparelWomensYoung ApparelMens ApparelMensBigAndTall  \
# 0                     Y                  N           N                     N
# 1                     N                  Y           N                     N
#
#   ApparelMensYoung ApparelChildrens HealthAndBeauty BeautyCosmetics  ...  \
# 0                N                N               Y               Y  ...
# 1                N                N               N               Y  ...
#
#   DietingWeightLoss SelfImprovement AutoPartsAndAccessories         HomeValue  \
# 0                 Y               Y                       N  $300,000-349,999
# 1                 Y               N                       N  $275,000-299,999
#
#   HomePurchaseDate HomePurchasePrice MortgageMostRecentLenderName  \
# 0       06/23/2008             215.0                STATE SVGS BK
# 1       12/08/2008             310.0    THIRD FED'L S&L/CLEVELAND
#
#   HomeYearBuilt HomeAirConditioning HomePool HomeFuel       HomeSewer  \
# 0        1995.0                   A      NaN      Gas             NaN
# 1        2001.0                   A      NaN      Gas  Sewer - Public
#
#         HomeWater LoanToValue EthnicCode       EthnicGroup Language  \
# 0             NaN        11.0   Scottish  Western European  English
# 1  Water - Public        24.0     German  Western European  English
#
#      Religion CreditRating Latitude Longitude ValueHunter OpportunitySeekers  \
# 0  Protestant         800+  40.1416  -82.8882         NaN                NaN
# 1  Protestant      750-799  41.3578  -81.9360           Y                  Y
#
#   NewsAndFinancial AutomotiveBuff ComputerOwner CookingEnthusiast  \
# 0              NaN              Y             Y                 Y
# 1                Y              Y             Y                 Y
#
#   DoItYourselfer ExerciseEnthusiast OutdoorEnthusiast OutdoorSportsLover  \
# 0              Y                  Y                 Y                  Y
# 1            NaN                  Y                 Y                  Y
#
#   Photography Traveler ReligiousMagazines MaleMerchandiseBuyer  \
# 0           Y        Y                  Y                  NaN
# 1           Y        Y                NaN                  NaN
#
#   FemaleMerchandiseBuyer GardeningFarmingBuyer BookBuyer SpecialFoodsBuyer  \
# 0                      Y                     Y         Y                 Y
# 1                      Y                     Y         Y                 Y
#
#   HighTechLeader DonatesToEnvironmentalCauses DonatesByMail IsCharitable  \
# 0              Y                            Y           NaN            Y
# 1              Y                          NaN           NaN            Y
#
#   ChildrensProductsGeneral ResidentialDeliveryIndicator HomeRefinanceDate  \
# 0                      NaN                            Y        08/31/2003
# 1                        Y                            Y        07/21/2001
#
#   RefinanceAmount        RefinanceLenderName DomainRegistered RegistrarName
# 0            36.0     WELLS FARGO HM MTG INC              NaN           NaN
# 1            70.0  THIRD FED'L S&L/CLEVELAND              NaN           NaN
#
# [2 rows x 286 columns]

# %% [markdown]
# ### Read CSV File

# %%
# Read CSV file into dataframe
df_titanic = pd.read_csv('Titanic Passenger data.csv', encoding="latin1", index_col = None, header=0)

# %%
# Show data in last five rows
df_titanic.tail(5)
# Out:
#       Passenger Id Survived Ticket Class  \
# 1304           816       No    1st Class
# 1305           823       No    1st Class
# 1306          1044       No    3rd Class
# 1307          1158       No    1st Class
# 1308          1264       No    1st Class
#
#                                        Name      Title Last Name   Sex   Age  \
# 1304                       Fry, Mr. Richard        Mr.       Fry  male   NaN
# 1305        Reuchlin, Jonkheer. John George  Jonkheer.  Reuchlin  male  38.0
# 1306                     Storey, Mr. Thomas        Mr.    Storey  male  60.5
# 1307  Chisholm, Mr. Roderick Robert Crispin        Mr.  Chisholm  male   NaN
# 1308                Ismay, Mr. Joseph Bruce        Mr.     Ismay  male  49.0
#
#       Siblings & Spouses on Ship  Parents & Children on Ship Ticket Number  \
# 1304                           0                           0        112058
# 1305                           0                           0         19972
# 1306                           0                           0          3701
# 1307                           0                           0        112051
# 1308                           0                           0        112058
#
#        Fare Cabin Number Port of Embarkment
# 1304  0.00         B102        Southampton
# 1305  0.00          NaN        Southampton
# 1306  0.00          NaN        Southampton
# 1307  0.00          NaN        Southampton
# 1308  0.00  B52 B54 B56        Southampton

# %% [markdown]
# ### Read Web Data

# %%
# Import library to read websites
import urllib.request

# Specify which URL/web page we are going to be scraping
url = "https://en.wikipedia.org/wiki/List_of_all-time_NFL_win%E2%80%93loss_records"

# Open the url using urllib.request and put the HTML into the page variable
page = urllib.request.urlopen(url)

# %%
# Import the BeautifulSoup library so we can parse HTML and XML documents
from bs4 import BeautifulSoup

# Parse the HTML from the URL into the BeautifulSoup parse tree format
soup = BeautifulSoup(page, "lxml")

# Import the first table into a Python variable
win_loss_table = soup.find('table', class_='wikitable sortable')

# Show win-loss table in HTML
win_loss_table
# Out:
# <table border="1" class="wikitable sortable">
# <tbody><tr align="center">
# <th>Rank</th>
# <th>Team</th>
# <th><abbr title="Total games played">GP</abbr></th>
# <th>Won</th>
# <th>Lost</th>
# <th>Tied</th>
# <th>Pct.</th>
# <th>First NFL Season</th>
# <th>Division
# </th></tr>
# <tr align="center">
# <td>1</td>
# <td><a href="/wiki/Dallas_Cowboys" title="Dallas Cowboys">Dallas Cowboys</a></td>
# <td>914</td>
# <td>520</td>
# <td>388</td>
# <td>6</td>
# <td>.572</td>
# <td><a href="/wiki/1960_Dallas_Cowboys_season" title="1960 Dallas Cowboys season">1960</a></td>
# <td bgcolor="#D0E7FF"><a href="/wiki/NFC_East" title="NFC East">NFC East</a>
# </td></tr>
# <tr align="center">
# <td>2</td>
# <td><a href="/wiki/Green_Bay_Packers" title="Green Bay Packers">Green Bay Packers</a></td>
# <td>1,368</td>
# <td>756</td>
# <td>574</td>
# <td>38</td>
# <td>.567</td>
# <td><a href="/wiki/1921_Green_Bay_Packers_season" title="1921 Green Bay Packers season">1921</a></td>
# <td bgcolor="#D0E7FF">NFC North
# </td></tr>
# <tr align="center">
# <td>3</td>
# <td><a href="/wiki/New_England_Patriots" title="New England Patriots">New England Patriots</a></td>
# <td>916</td>
# <td>512</td>
# <td>395</td>
# <td>9</td>
# <td>.564</td>
# <td><a href="/wiki/1960_Boston_Patriots_season" title="1960 Boston Patriots season">1960</a></td>
# <td bgcolor="#D0E7FF">AFC East
# </td></tr>
# <tr align="center">
# <td>4</td>
# <td><a href="/wiki/Chicago_Bears" title="Chicago Bears">Chicago Bears</a></td>
# <td>1,402</td>
# <td>769</td>
# <td>591</td>
# <td>42</td>
# <td>.563</td>
# <td><a href="/wiki/1920_Decatur_Staleys_season" title="1920 Decatur Staleys season">1920</a></td>
# <td><a href="/wiki/NFC_North" title="NFC North">NFC North</a>
# </td></tr>
# <tr align="center">
# <td>5</td>
# <td><a href="/wiki/Baltimore_Ravens" title="Baltimore Ravens">Baltimore Ravens</a></td>
# <td>384</td>
# <td>214</td>
# <td>169</td>
# <td>1</td>
# <td>.559</td>
# <td><a href="/wiki/1996_Baltimore_Ravens_season" title="1996 Baltimore Ravens season">1996</a></td>
# <td bgcolor="#D0E7FF"><a href="/wiki/AFC_North" title="AFC North">AFC North</a>
# </td></tr>
# <tr align="center">
# <td>6</td>
# <td><a href="/wiki/Miami_Dolphins" title="Miami Dolphins">Miami Dolphins</a></td>
# <td>832</td>
# <td>457</td>
# <td>371</td>
# <td>4</td>
# <td>.552</td>
# <td><a href="/wiki/1966_Miami_Dolphins_season" title="1966 Miami Dolphins season">1966</a></td>
# <td><a href="/wiki/AFC_East" title="AFC East">AFC East</a>
# </td></tr>
# <tr align="center">
# <td>7</td>
# <td><a href="/wiki/Minnesota_Vikings" title="Minnesota Vikings">Minnesota Vikings</a></td>
# <td>902</td>
# <td>488</td>
# <td>403</td>
# <td>11</td>
# <td>.547</td>
# <td><a href="/wiki/1961_Minnesota_Vikings_season" title="1961 Minnesota Vikings season">1961</a></td>
# <td>NFC North
# </td></tr>
# <tr align="center">
# <td>8</td>
# <td><a href="/wiki/San_Francisco_49ers" title="San Francisco 49ers">San Francisco 49ers</a></td>
# <td>1,034</td>
# <td>545</td>
# <td>475</td>
# <td>14</td>
# <td>.534</td>
# <td><a href="/wiki/1950_San_Francisco_49ers_season" title="1950 San Francisco 49ers season">1950</a></td>
# <td bgcolor="#D0E7FF"><a href="/wiki
# <td>1,265</td>
# <td>562</td>
# <td>670</td>
# <td>33</td>
# <td>.457</td>
# <td><a href="/wiki/1930_Portsmouth_Spartans_season" title="1930 Portsmouth Spartans season">1930</a></td>
# <td>NFC North
# </td></tr>
# <tr align="center">
# <td>26</td>
# <td><a href="/wiki/Houston_Texans" title="Houston Texans">Houston Texans</a></td>
# <td>288</td>
# <td>131</td>
# <td>157</td>
# <td>0</td>
# <td>.455</td>
# <td><a href="/wiki/2002_Houston_Texans_season" title="2002 Houston Texans season">2002</a></td>
# <td>AFC South
# </td></tr>
# <tr align="center">
# <td>27</td>
# <td><a href="/wiki/New_York_Jets" title="New York Jets">New York Jets</a></td>
# <td>916</td>
# <td>408</td>
# <td>500</td>
# <td>8</td>
# <td>.450</td>
# <td><a href="/wiki/1960_New_York_Titans_season" title="1960 New York Titans season">1960</a></td>
# <td>AFC East
# </td></tr>
# <tr align="center">
# <td>28</td>
# <td><a href="/wiki/Cincinnati_Bengals" title="Cincinnati Bengals">Cincinnati Bengals</a></td>
# <td>804</td>
# <td>359</td>
# <td>441</td>
# <td>4</td>
# <td>.449</td>
# <td><a href="/wiki/1968_Cincinnati_Bengals_season" title="1968 Cincinnati Bengals season">1968</a></td>
# <td>AFC North
# </td></tr>
# <tr align="center">
# <td>29</td>
# <td><a href="/wiki/Atlanta_Falcons" title="Atlanta Falcons">Atlanta Falcons</a></td>
# <td>832</td>
# <td>365</td>
# <td>461</td>
# <td>6</td>
# <td>.448</td>
# <td><a href="/wiki/1966_Atlanta_Falcons_season" title="1966 Atlanta Falcons season">1966</a></td>
# <td>NFC South
# </td></tr>
# <tr align="center">
# <td>30</td>
# <td><a href="/wiki/Jacksonville_Jaguars" title="Jacksonville Jaguars">Jacksonville Jaguars</a></td>
# <td>400</td>
# <td>176</td>
# <td>224</td>
# <td>0</td>
# <td>.440</td>
# <td><a href="/wiki/1995_Jacksonville_Jaguars_season" title="1995 Jacksonville Jaguars season">1995</a></td>
# <td>AFC South
# </td></tr>
# <tr align="center">
# <td>31</td>
# <td><a href="/wiki/Arizona_Cardinals" title="Arizona Cardinals">Arizona Cardinals</a></td>
# <td>1,362</td>
# <td>558</td>
# <td>763</td>
# <td>41</td>
# <td>.425</td>
# <td><a href="/wiki/1920_Chicago_Cardinals_season" title="1920 Chicago Cardinals season">1920</a></td>
# <td>NFC West
# </td></tr>
# <tr align="center">
# <td>32</td>
# <td><a href="/wiki/Tampa_Bay_Buccaneers" title="Tampa Bay Buccaneers">Tampa Bay Buccaneers</a></td>
# <td>692</td>
# <td>267</td>
# <td>424</td>
# <td>1</td>
# <td>.387</td>
# <td><a href="/wiki/1976_Tampa_Bay_Buccaneers_season" title="1976 Tampa Bay Buccaneers season">1976</a></td>
# <td>NFC South
# </td></tr></tbody></table>

# %%
# Create a list for each column in the table
A=[]; B=[]; C=[]; D=[]; E=[]; F=[]; G=[]; H=[]; I=[]

# We are going to ingore the headers in the <th> tags and create our own headers, but these could be imported too
# Go through the rows in the table and put the contents in the appropriate list
for row in win_loss_table.findAll('tr'):
    cells=row.findAll('td')
    if len(cells)==9:
        A.append(cells[0].find(text=True))
        B.append(cells[1].find(text=True))
        C.append(cells[2].find(text=True))
        D.append(cells[3].find(text=True))
        E.append(cells[4].find(text=True))
        F.append(cells[5].find(text=True))
        G.append(cells[6].find(text=True))
        H.append(cells[7].find(text=True))
        I.append(cells[8].find(text=True))

# %%
# Create a data frame with our specific column headers and append the data from the lists under each header
df_nfl = pd.DataFrame(data = A, columns=['Rank'])
df_nfl['Team'] = B
df_nfl['Games Played'] = C
df_nfl['Games Won'] = D
df_nfl['Games Lost'] = E
df_nfl['Games Tied'] = F
df_nfl['Percentage Won'] = G
df_nfl['First NFL Season'] = H
df_nfl['Team Division'] = I

# Data comes in as objects (strings). Convert certain fields to numbers after removing commas
df_nfl['Rank'] = pd.to_numeric(df_nfl['Rank'])
df_nfl['Games Played'] = pd.to_numeric(df_nfl['Games Played'].str.replace(',', ''))
df_nfl['Games Won'] = pd.to_numeric(df_nfl['Games Won'].str.replace(',', ''))
df_nfl['Games Lost'] = pd.to_numeric(df_nfl['Games Lost'].str.replace(',', ''))
df_nfl['Games Tied'] = pd.to_numeric(df_nfl['Games Tied'].str.replace(',', ''))
df_nfl['Percentage Won'] = pd.to_numeric(df_nfl['Percentage Won'])
df_nfl['First NFL Season'] = pd.to_numeric(df_nfl['First NFL Season'])

# Reset index to rank field
df_nfl.set_index('Rank', inplace=True)

# Show current condition of dataframe fields
df_nfl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32 entries, 1 to 32
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Team              32 non-null     object
#  1   Games Played      32 non-null     int64
#  2   Games Won         32 non-null     int64
#  3   Games Lost        32 non-null     int64
#  4   Games Tied        32 non-null     int64
#  5   Percentage Won    32 non-null     float64
#  6   First NFL Season  32 non-null     int64
#  7   Team Division     32 non-null     object
# dtypes: float64(1), int64(5), object(2)
# memory usage: 2.2+ KB

# %% [markdown]
# # Show 4 specific rows of data in the dataframe starting with row 5.
# # Remember, Python starts at 0 not 1 in indexing rows.

# %%
df_nfl[4:8]
# Out:
#                      Team  Games Played  Games Won  Games Lost  Games Tied  \
# Rank
# 5        Baltimore Ravens           384        214         169           1
# 6          Miami Dolphins           832        457         371           4
# 7       Minnesota Vikings           902        488         403          11
# 8     San Francisco 49ers          1034        545         475          14
#
#       Percentage Won  First NFL Season Team Division
# Rank
# 5              0.559              1996     AFC North
# 6              0.552              1966      AFC East
# 7              0.547              1961   NFC North\n
# 8              0.534              1950      NFC West

# %% [markdown]
# ## Python Assignment 1
# ### Name: George Gannon

# %%
df_datafinder.sample(1)   # Shows a random sample of one row from dataframe
# Out:
#             City County State    Zip Country         DOB  URLSource  AutoYear  \
# 1333  HORSE CAVE   Hart    KY  42749     NaN  07/00/1966  GOING.COM    2000.0
#
#        Make    Model AutoTrim            AutoVIN Gender     Source  Last4SSN  \
# 1333  DODGE  CARAVAN    WAGON  2B4GP2535YR619992   Male  GOING.COM    2207.0
#
#      Employer   Occupation  LoanAmount LoanType  MonthlyIncome  \
# 1333      NaN  Blue Collar         NaN      NaN            NaN
#
#      EstimatedHouseholdIncome        NetWorth  NumberCreditLines  \
# 1333           $40,000-44,999  $25,000-49,999                3.0
#
#      RangeOfNewCredit              Education OccupationDetail  \
# 1333              NaN  Completed High School              NaN
#
#       NumberOfChildren PresenceOfChildren MaritalStatusInHousehold  \
# 1333               1.0                  Y                        A
#
#      HomeOwnerRenter  LengthOfResidence DwellingType  NumberOfAdults  \
# 1333               H                 14            S               2
#
#       HouseholdSize  GenerationsInHousehold MailOrderBuyer  \
# 1333              3                     2.0              Y
#
#      MailerOrderResponder OnlinePurchasingIndicator MembershipClubs  \
# 1333                    Y                         N               N
#
#      ValuePriceGeneralMerchandiseBuyer ApparelWomens ApparelWomensPetite  \
# 1333                                 N             N                   N
#
#      ApparelWomensPlusSize ApparelWomensYoung ApparelMens  \
# 1333                     N                  N           N
#
#      ApparelMensBigAndTall ApparelMensYoung ApparelChildrens HealthAndBeauty  \
# 1333                     N                N                N               N
#
#      BeautyCosmetics  ... DietingWeightLoss SelfImprovement  \
# 1333               N  ...                 Y               N
#
#      AutoPartsAndAccessories       HomeValue HomePurchaseDate  \
# 1333                       N  $75,000-99,999       05/00/2003
#
#      HomePurchasePrice MortgageMostRecentLenderName HomeYearBuilt  \
# 1333               5.0                          NaN        2003.0
#
#      HomeAirConditioning HomePool HomeFuel HomeSewer HomeWater LoanToValue  \
# 1333                   A      NaN      NaN       NaN       NaN         NaN
#
#      EthnicCode       EthnicGroup Language    Religion CreditRating Latitude  \
# 1333   Scottish  Western European  English  Protestant      700-749  37.2213
#
#      Longitude ValueHunter OpportunitySeekers NewsAndFinancial AutomotiveBuff  \
# 1333  -85.8652           Y                NaN              NaN              Y
#
#      ComputerOwner CookingEnthusiast DoItYourselfer ExerciseEnthusiast  \
# 1333             Y                 Y            NaN                  Y
#
#      OutdoorEnthusiast OutdoorSportsLover Photography Traveler  \
# 1333                 Y                  Y         NaN        Y
#
#      ReligiousMagazines MaleMerchandiseBuyer FemaleMerchandiseBuyer  \
# 1333                  Y                  NaN                    NaN
#
#      GardeningFarmingBuyer BookBuyer SpecialFoodsBuyer HighTechLeader  \
# 1333                     Y         Y               NaN            NaN
#
#      DonatesToEnvironmentalCauses DonatesByMail IsCharitable  \
# 1333                          NaN           NaN          NaN
#
#      ChildrensProductsGeneral ResidentialDeliveryIndicator HomeRefinanceDate  \
# 1333                      NaN                            Y               NaN
#
#      RefinanceAmount RefinanceLenderName DomainRegistered RegistrarName
# 1333             NaN                 NaN              NaN           NaN
#
# [1 rows x 286 columns]

# %%
df_titanic.sample(1)   # Shows a random sample of one row from dataframe
# Out:
#       Passenger Id Survived Ticket Class  \
# 1240           927       No    3rd Class
#
#                                                   Name Title  Last Name   Sex  \
# 1240  Katavelas, Mr. Vassilios (Catavelas Vassilios")"   Mr.  Katavelas  male
#
#        Age  Siblings & Spouses on Ship  Parents & Children on Ship  \
# 1240  18.5                           0                           0
#
#      Ticket Number   Fare Cabin Number Port of Embarkment
# 1240          2682  7.23          NaN          Cherbourg

# %%
df_nfl.sample(1)   # Shows a random sample of one row from dataframe
# Out:
#                 Team  Games Played  Games Won  Games Lost  Games Tied  \
# Rank
# 6     Miami Dolphins           832        457         371           4
#
#       Percentage Won  First NFL Season Team Division
# Rank
# 6              0.552              1966      AFC East

# %%
import datetime, socket
print(datetime.datetime.now().isoformat())
print("Your Computer Name is: " + socket.gethostname())
print("Your Computer IP Address is: " + socket.gethostbyname(socket.gethostname()))
# Out:
# 2020-08-26T16:51:49.243843
# Your Computer Name is: DESKTOP-0VRDGNF
# Your Computer IP Address is: 192.168.1.139
