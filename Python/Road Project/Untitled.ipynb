# %%
###
"Biology Department Forms:
Drop/Add/Late Registration
MTSU Undergraduate Course Substitution Form
Intent to Graduate Form
CBAS Request for Credit Overload
Request to Repeat Courses
Waiver of Total Upper Division Hours
Upper Division Form
Volunteer Form

Honors College Forms:
Thesis Tutorial
Honors Contract
Statement of Intent to Graduate from the University Honors College
Internship Credit Substitution Request Form
Passport Assistance Scholarship
Student Thesis Proposal Assessment Form (UH 4900)
Student Honors Thesis Assessment Form (UH 4950)
Mid-Semester Honors Thesis/Creative Project Report
Study Abroad Scholarship/Intent Form
Request for Independent Study Approval Form
Thesis Formatting Checklist
Thesis Publishing Agreement
Application for Undergraduate Work Study"

# %%
# Import library to read websites
import urllib.request

# Specify which URL/web page we are going to be scraping
url = "https://www.mtsu.edu/biology/student-forms.php"

# Open the url using urllib.request and put the HTML into the page variable
page = urllib.request.urlopen(url)

# %%
# Import the BeautifulSoup library so we can parse HTML and XML documents
from bs4 import BeautifulSoup

# Parse the HTML from the URL into the BeautifulSoup parse tree format
soup = BeautifulSoup(page, "lxml")

soup
# Out:
# <!DOCTYPE HTML>
# <html lang="en">
# <head>
# <!--META INFO ====================================================-->
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <meta content="all" name="robots"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="" name="custom-metadata"/>
# <title>Department of Biology | Middle Tennessee State University</title>
# <!--START CANONICAL - XSL HACK ====================================================--><link href="https://www.mtsu.edu/biology/student-forms.php" rel="canonical"/>
# <!-- END CANONICAL - XSL HACK -->
# <!-- com.omniupdate.properties -->
# <meta content="" name="keywords"/>
# <meta content="" name="description"/>
# <!-- /com.omniupdate.properties -->
# <meta content="" property="og:title"/>
# <meta content="https://www.mtsu.edu/biology/student-forms.php" property="og:url"/>
# <meta content="" property="og:description"/>
# ...

# %%
Bio_forms = ['Drop/Add/Late Registration',
'MTSU Undergraduate Course Substitution Form',
'Intent to Graduate Form',
'CBAS Request for Credit Overload',
'Request to Repeat Courses',
'Waiver of Total Upper Division Hours',
'Upper Division Form',
'Volunteer Form']

# %%
# Import the first table into a Python variable
win_loss_table = soup.find('table',class_="full_table")

# Show win-loss table in HTML
win_loss_table
# Out:
# <table class="full_table">
# <tbody>
# <tr>
# <th>form</th>
# <th style="width: 10%;">type</th>
# </tr>
# <tr>
# <td><a href="/registration/docs/dropadd.pdf">Add/Drop/Late Registration Form</a></td>
# <td>PDF</td>
# </tr>
# <tr>
# <td><a href="/one-stop/docs/REGsub.pdf">Course Substitution Form</a></td>
# <td>PDF</td>
# </tr>
# <tr>
# <td><a href="/one-stop/docs/intentform.pdf">Intent to Graduate</a></td>
# <td>PDF</td>
# </tr>
# <tr>
# <td><a href="/cbas-advising/docs/request_for_overload_form.pdf">Request for Overload</a></td>
# <td>DOC</td>
# </tr>
# <tr>
# <td><a href="/one-stop/docs/repeatcourse.pdf">Request to Repeat</a></td>
# <td>DOC</td>
# </tr>
# <tr>
# <td><a href="/biology/docs/UD-waiver.doc" target="_blank">Upper Division Waiver</a></td>
# <td>PDF </td>
# </tr>
# <tr>
# <td><a href="/biology/docs/Biology-UD-form-2009-11.pdf" target="_blank">Upper Division Form 2009-2011</a></td>
# <td>PDF </td>
# </tr>
# <tr>
# ...

# %%
A=[]

# We are going to ingore the headers in the <th> tags and create our own headers, but these could be imported too
# Go through the rows in the table and put the contents in the appropriate list
for row in win_loss_table.findAll('tr'):
    cells=row.findAll('td')
    A.append(cells)

# %%
for index in range(len(Bio_forms)):
    doc = Bio_forms[index]
    print(doc)
    if doc in A:
        print(url)
# Out:
# Drop/Add/Late Registration
# MTSU Undergraduate Course Substitution Form
# Intent to Graduate Form
# CBAS Request for Credit Overload
# Request to Repeat Courses
# Waiver of Total Upper Division Hours
# Upper Division Form
# Volunteer Form

# %%
    "for j in range(len(A)-index):
        check = A[j]
        print(check)
        if doc in check:
            print(doc)
